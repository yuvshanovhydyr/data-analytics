# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd


url = "https://btech-data-analytics.github.io/bridgerland-technical-college/employees_3.html"


response = requests.get(url)


soup = BeautifulSoup(response.text, 'html.parser')


table = soup.find('table')


headers = []
for th in table.find_all('th'):
    headers.append(th.text.strip())


rows = []
for tr in table.find_all('tr')[1:]: 
    cells = tr.find_all('td')
    row = [cell.text.strip() for cell in cells]
    if row: 
        rows.append(row)


df = pd.DataFrame(rows, columns=headers)


df['Age'] = pd.to_numeric(df['Age'])


average_age = df['Age'].mean()
std_dev_age = df['Age'].std()


print("DataFrame:")
print(df)

print("\nAverage Age:", average_age)
print("Standard Deviation of Age:", round(std_dev_age, 2))
# Out:
# DataFrame:
#     ID            Name  Age
# 0  101        John Doe   28
# 1  102      Jane Smith   32
# 2  103  Robert Johnson   24
# 3  104    Mary Johnson   29
# 4  105   Michael Brown   35
# 5  106     Susan Davis   27
# 6  107    David Wilson   31
# 7  108    Linda Miller   33
#
# Average Age: 29.875
# Standard Deviation of Age: 3.56
