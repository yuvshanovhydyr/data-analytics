# %%
import seaborn as sns
import pandas as pd 
import matplotlib.pyplot as plt
import os
df = pd.read_csv(r"C:\Users\user\Desktop\.ipynb_checkpoints\housing.csv")
df.head()
df.head()
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Landsize', y='Price', hue='Type')
plt.title('Land Size vs Price by Property Type')
plt.xlabel('Land Size (m²)')
plt.ylabel('Price ($)')
plt.tight_layout()
plt.show()

avg_price_year = df.groupby('YearBuilt')['Price'].mean().reset_index()

plt.figure(figsize=(12, 6))
sns.lineplot(data=avg_price_year, x='YearBuilt', y='Price')
plt.title('Average Price by Year Built')
plt.xlabel('Year Built')
plt.ylabel('Average Price ($)')
plt.tight_layout()
plt.show()

avg_price_region = df.groupby('Regionname')['Price'].mean().reset_index()

plt.figure(figsize=(12, 6))
sns.barplot(data=avg_price_region, x='Regionname', y='Price')
plt.title('Average Price by Region')
plt.xlabel('Region')
plt.ylabel('Average Price ($)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='Price', bins=50)
plt.title('Distribution of Property Prices')
plt.xlabel('Price ($)')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

plt.figure(figsize=(12, 8))
sns.boxplot(data=df, x='YearBuilt', y='Regionname', orient='h')
plt.title('Year Built by Region')
plt.xlabel('Year Built')
plt.ylabel('Region')
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import pandas as pd 
import matplotlib.pyplot as plt
import os
df = pd.read_csv(r"C:\Users\user\Desktop\.ipynb_checkpoints\housing.csv")
df.head()
# Out:
#        Suburb          Address  Rooms   Type    Price               Method  \
# 0  Abbotsford  25 Bloomburg St      2  house  1035000        property sold
# 1  Abbotsford     5 Charles St      3  house  1465000  property sold prior
# 2  Abbotsford      55a Park St      4  house  1600000           vendor bid
# 3  Abbotsford     124 Yarra St      3  house  1876000        property sold
# 4  Abbotsford    98 Charles St      2  house  1636000        property sold
#
#   SellerG       Date  Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# 0  Biggin   4/2/2016       2.5      3067         2         1  0.0       156
# 1  Biggin   4/3/2017       2.5      3067         3         2  0.0       134
# 2  Nelson   4/6/2016       2.5      3067         3         1  2.0       120
# 3  Nelson   7/5/2016       2.5      3067         4         2  0.0       245
# 4  Nelson  8/10/2016       2.5      3067         2         1  2.0       256
#
# ...
