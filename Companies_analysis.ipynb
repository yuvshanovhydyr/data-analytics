# %%
import seaborn as sns 
import pandas as pd
import matplotlib.pyplot as plt 
df = pd. read_csv('companies.csv')
df.head()
plt.figure(figsize=(14, 8)) 
sns.countplot(x = 'state', data = df)
plt.show()
#check
df.head()
plt.figure(figsize=(25, 8)) 
sns.barplot(x='Industry', y='job_openings', data=df, estimator=sum )
plt.show()

# %%
import seaborn as sns 
import pandas as pd
import matplotlib.pyplot as plt 
df = pd. read_csv('companies.csv')
plt.figure(figsize=(25, 8)) 
sns.lineplot(x='founded', y='growth_percentage',data= df, linewidth=4)
plt.figure(figsize=(10,8))
sns.scatterplot(x='employees', y='estimated_revenues', data=df, hue='Industry')
plt.show()
sns.histplot(x='founded', data=df, color='green')
plt.show()
